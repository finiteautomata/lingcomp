# %% [markdown]
# <a href="https://colab.research.google.com/github/finiteautomata/lingcomp/blob/master/Taller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detección de regionalismos en Twitter
#
# En esta notebook, mostraremos cómo calcular regionalismos en base a tweets extraídos de las provincias argentinas.
#
# Si bien todas las palabras que encontraremos no son necesariamente regionalismos, sí trataremos de encontrar palabras que guarden alguna correlación geográfica: por ejemplo, nombres de políticos, topónimos (ciudades, lugares, etc)
#
# ## Tecnologías que usaremos
#
# Para ello utilizaremos el entorno de desarrollo Google Colab, que se basa en el lenguaje `Python`  y Jupyter.

# %% [markdown]
# ## Cargar los datos
# En primer lugar, carguemos los datos. Esto lo haremos con la librería `pandas` que, a grandes rasgos, nos permite trabajar con datos tabulados de una manera muy sencilla.
#
# Cada "fila" de esta tabla representa a un usuario de la muestra que tenemos.

# %%
import pandas as pd


df = pd.read_json("https://raw.githubusercontent.com/finiteautomata/lingcomp/master/data/users_small.json")
print("Tenemos {} usuarios".format(len(df)))
df[:10]
# Out:
# Tenemos 1000 usuarios
#                  provincia                                               text
# 1001198857  tierradelfuego  Que lindo fue escucharla hoy a mi hija decir '...
# 1006781437  tierradelfuego  Que cagaso me da ir a entrenar con estos rayos...
# 101534453            jujuy  #Jujuy: encuentran a toda una familia muerta e...
# 1015480064        rionegro  Que embole chabonnn\nNunca me subestimes aaa\n...
# 1017761377         formosa  Me hace tanto bien estar con mis amigos!!!\nat...
# 1019018742         formosa  Cuántos segundos tarda una sonrisa nuestra en ...
# 1019973290         mendoza  Quiero ir al cine 🙌\nMientras exista un 1% de ...
# 1024515116         sanjuan  Nos pusieron aire, no damos mas de felicess🙌🙌 ...
# 1025513040  tierradelfuego  Que lindo tener a fer en mi vida♡\nEstoy muy c...
# 1029563737         neuquen  Que bien el barca, mucho huevo\nConfió en vos....

# %% [markdown]
# Calculemos las provincias que vienen en el dataset

# %%
provincias = df["provincia"].unique()

print("Tabla con cantidad de usuarios por provincia")
df.groupby("provincia").count()
# Out:
# Tabla con cantidad de usuarios por provincia
#                 text
# provincia
# buenosaires       42
# catamarca         49
# chaco             38
# chubut            46
# cordoba           40
# corrientes        47
# entrerios         42
# formosa           48
# jujuy             42
# lapampa           43
# larioja           48
# mendoza           41
# misiones          42
# neuquen           35
# rionegro          50
# salta             45
# sanjuan           41
# sanluis           43
# santacruz         41
# santafe           40
# santiago          44
# tierradelfuego    52
# tucuman           41

# %% [markdown]
# Veamos un poco mejor qué información tiene cada usuario:

# %%
def show_info(user_number):
  row = df.iloc[user_number]
  print("Usuario de {}\n\n".format(row["provincia"]))
  
  print("Algunos tweets:\n")
  
  tweets = row["text"].split("\n")
  
  for (i, tweet) in zip(range(40), tweets):
      print(tweet)


#
# si cambiamos el 77 por cualquier número entre 0 y 999 y ejecutamos (shift+enter)
# podremos ver qué información de cada usuario tenemos
show_info(99)
# Out:
# Usuario de sanjuan
#
#
# Algunos tweets:
#
# @perroscalle todos a Irlandaaa!
# @MutanteMariposa aca corrió, huyó, como debe ser!, se lo dice cobardemente a un empleado, y No a los dueños. Creo q sabemos quien puede ser!
# Nooooooooo, volver a trabajar despues del Feriado!. Solucion: un Happy Hour en Leinster Bar. Temprano. Mañana Jueve… https://t.co/EwGRhOnweW
# @bastatodo @soyjuandinatale lo vamos a escuchar a Full!, Grandioso el canoso mas groso de la radio!...que vuelva!. Aguante Juan y Basta DT.
# Vos tranquilo gato, tomamos despacio!!!. #PlayDog #ElPerroMasGato #LeinsterBar #Sanjuaninos #CervezaArtesanal… https://t.co/HcdELqPVMx
# Seguimos a pleno!!!, suenan los Creedence Clearwater!
# Clientes "gata flora" salir, entrar, mesa pasto, mesa adentro, mesa en el techo, afuera, abajo del arbol!!!, llueve: todos adentro y bastaaa
# @ElinaGonza esa es la hinchada de verdad!, la que nunca abandona el Irlandes ☘☘☘ . Usted es 🥇🤙🍺
# Llevenme a tomar una birra a Leinster Nietitas pillas... https://t.co/efW4ZdGZ7o
# @bastatodo como se llaman las chicas Country que tocaron en Vivo recien? Gracias!!!
# La La Land Tened Adentro !. Vayan a tomar unas birras, y curar penas...
# Asi terminaron los Oscar? https://t.co/wY2j1nmtdi
# Rojo / Colorado...Pieza / Cuarto...Malla / Traje de baño...Birra / Cerveza... el mismo significado pero con distinto glamour?

# %% [markdown]
# ## Tokenización
#
# Para poder analizar el léxico de cada tweet, necesitamos separarlos en "tokens" – es decir, en las unidades que nosotros consideremos. Este proceso se llama "tokenización", y para ello utilizaremos la librería [nltk](https://www.nltk.org/) (Natural Language ToolKit), nuestra navaja suiza para procesar texto.

# %%
import re
from nltk.tokenize import TweetTokenizer

_tokenizer = TweetTokenizer(
    preserve_case=False,
    reduce_len=True,
    strip_handles=True
)

urls = r'(?:https?\://t.co/[\w]+)'


def tokenize(text, only_alpha=True, remove_hashtags=True):
    """
    Tokenize tweet
    """
    
    tokens = _tokenizer.tokenize(text)

    if only_alpha:
        tokens = [tk for tk in tokens if tk.isalpha()]
    else:
        if remove_hashtags:
            tokens = [tk for tk in tokens if tk[0] != "#"]
        tokens = [tk for tk in tokens if not re.match(urls, tk)]
    return tokens

  
tokenize("Hola a TODOSSS!!! http://www.google.com.ar 😄😄")
# Out:
# ['hola', 'a', 'todosss']

# %% [markdown]
# Ahora, armemos una tabla de doble entrada de las palabras a la cantidad de veces (y de usuarios) que tienen por provincia

# %%
# %%time

word_to_tweets = {}

def build_dataframe_from_users(users):
    """
    Build dataframe from users.

    Arguments:
    ---------

    users: Iterable of dicts having "text" key

    Returns:
    --------

    df: pandas.DataFrame

        DataFrame of occurrences of words in provinces
    """

    def get_bow(user):
        bow = {}
        province = user["provincia"]
        tweets = user["text"].split("\n")
        
        for tweet in tweets:
            tokens = tokenize(tweet)
            for token in tokens:
                if token not in word_to_tweets:
                    word_to_tweets[token] = []
                
                word_to_tweets[token].append((province, tweet))
                bow[token] = bow.get(token, 0) + 1
        return bow

    columns = {}

    for user in users:
        bow = get_bow(user)
        province = user["provincia"]

        occ_column = province + "_ocurrencias"
        user_column = province + "_usuarios"

        if occ_column not in columns:
            columns[occ_column] = {}
            columns[user_column] = {}

        for tok, count in bow.items():
            columns[occ_column][tok] = columns[occ_column].get(tok, 0) + count
            columns[user_column][tok] = columns[user_column].get(tok, 0) + 1


    df = pd.DataFrame.from_dict(columns)

    df.fillna(0, inplace=True)
    return df
  

word_df = build_dataframe_from_users(row for index, row in df.iterrows())
# Out:
# CPU times: user 1min 52s, sys: 66.9 ms, total: 1min 53s
# Wall time: 1min 53s

# %% [markdown]
# Veamos cómo se ve esto

# %%
word_df[:100]
# Out:
#                       buenosaires_ocurrencias  buenosaires_usuarios  \
# a                                     11153.0                  40.0
# aa                                       15.0                   6.0
# aaa                                      32.0                  11.0
# aaaa                                     11.0                   7.0
# aaaaa                                     2.0                   1.0
# aaaaaa                                    0.0                   0.0
# aaaaaaa                                   0.0                   0.0
# aaaaaaaa                                  0.0                   0.0
# aaaaaaaaa                                 0.0                   0.0
# aaaaaaaaaa                                0.0                   0.0
# aaaaaaaaaaa                               0.0                   0.0
# aaaaaaaaaaaaa                             0.0                   0.0
# aaaaaaaaaaaaaaa                           0.0                   0.0
# aaaaaaaaaaarriba                          0.0                   0.0
# aaaaaaaaaayyy                             0.0                   0.0
# aaaaaaaay                                 0.0                   0.0
# aaaaaaahh                                 0.0                   0.0
# aaaaaaahhh                                0.0                   0.0
# aaaaahhh                                  0.0                   0.0
# aaaabeeel                                 0.0                   0.0
# aaaabue                                   0.0                   0.0
# aaaaburrido                               0.0                   0.0
# aaaadentro                                0.0                   0.0
# aaaadfergthyjuikolpñ                      0.0                   0.0
# aaaag                                     0.0                   0.0
# aaaaggg                                   0.0                   0.0
# aaaagua                                   0.0                   0.0
# aaaaguuuaaannntaaa                        0.0                   0.0
# aaaah                                     0.0                   0.0
# aaaahaaah                                 0.0                   0.0
# ...                                       ...                   ...
# aaaammm                                   0.0                   0.0
# aaaamo                                    0.0                   0.0
# aaaamooorrr                               0.0                   0.0
# aaaamor                                   0.0                   0.0
# aaaandaa                                  0.0                   0.0
# aaaanooo                                  0.0                   0.0
# aaaaoowww                                 0.0                   0.0
# aaaapa                                    0.0                   0.0
# aaaapaaalala                              0.0                   0.0
# aaaaparece                                0.0                   0.0
# aaaappaaa                                 0.0                   0.0
# aaaaqii                                   0.0                   0.0
# aaaarre                                   0.0                   0.0
# aaaarriba                                 0.0                   0.0
# aaaarribaaa                               0.0                   0.0
# aaaascooo                                 0.0                   0.0
# aaaasi                                    0.0                   0.0
# aaaaspera                                 0.0                   0.0
# aaaaver                                   0.0                   0.0
# aaaaw                                     0.0                   0.0
# aaaawww                                   0.0                   0.0
# aaaay                                     0.0                   0.0
# aaaayayai                                 0.0                   0.0
# aaaayayayaya                              0.0                   0.0
# aaaaysss                                  0.0                   0.0
# aaaaaaaaaaa                       0.0                  0.0               0.0
# aaaaaaaaaaaaa                     0.0                  0.0               0.0
# aaaaaaaaaaaaaaa                   0.0                  0.0               0.0
# aaaaaaaaaaarriba                  0.0                  0.0               0.0
# aaaaaaaaaayyy                     0.0                  0.0               0.0
# aaaaaaaay                         0.0                  0.0               0.0
# aaaaaaahh                         0.0                  0.0               0.0
# aaaaaaahhh                        0.0                  0.0               0.0
# aaaaahhh                          0.0                  0.0               0.0
# aaaabeeel                         0.0                  0.0               0.0
# aaaabue                           0.0                  0.0               0.0
# aaaaburrido                       0.0                  0.0               0.0
# aaaadentro                        0.0                  0.0               0.0
# aaaadfergthyjuikolpñ              0.0                  0.0               0.0
# aaaag                             1.0                  0.0               0.0
# aaaaggg                           1.0                  0.0               0.0
# aaaagua                           1.0                  0.0               0.0
# aaaaguuuaaannntaaa                0.0                  0.0               0.0
# aaaah                             5.0                  4.0               1.0
# aaaahaaah                         0.0                  0.0               0.0
# ...                               ...                  ...               ...
# aaaammm                           1.0                  0.0               0.0
# aaaamo                            0.0                  0.0               0.0
# aaaamooorrr                       0.0                  0.0               0.0
# aaaamor                           0.0                  0.0               0.0
# aaaandaa                          1.0                  0.0               0.0
# aaaanooo                          0.0                  0.0               0.0
# aaaaoowww                         0.0                  0.0               0.0
# aaaapa                            0.0                  0.0               0.0
# aaaapaaalala                      0.0                  0.0               0.0
# aaaaparece                        0.0                  0.0               0.0
# aaaappaaa                         0.0                  0.0               0.0
# aaaaqii                           0.0                  0.0               0.0
# aaaarre                           0.0                  0.0               0.0
# aaaarriba                         0.0                  0.0               0.0
# aaaarribaaa                       0.0                  0.0               0.0
# aaaascooo                         0.0                  0.0               0.0
# aaaasi                            0.0                  0.0               0.0
# aaaaspera                         0.0                  0.0               0.0
# aaaaver                           0.0                  0.0               0.0
# aaaaw                             0.0                  0.0               0.0
# aaaawww                           0.0                  0.0               0.0
# aaaay                             1.0                  0.0               0.0
# aaaayayai                         0.0                  0.0               0.0
# aaaayayayaya                      0.0                  0.0               0.0
# aaaaysss                          0.0                  0.0               0.0
# aaaayy                            0.0                  0.0               0.0
# aaaayyy                           0.0                  0.0               0.0
# aaaazucar                         0.0                  0.0               0.0
# aaaazzzucar                       0.0                  0.0               0.0
# aaaaàaaahhh                       0.0                  0.0               0.0
#
#                             ...         santacruz_ocurrencias  \
# a                           ...                       10858.0
# aa                          ...                          13.0
# aaa                         ...                          11.0
# aaaa                        ...                           5.0
# aaaaa                       ...                           0.0
# aaaaaa                      ...                           0.0
# aaaaaaa                     ...                           0.0
# aaaaaaaa                    ...                           0.0
# aaaaaaaaa                   ...                           0.0
# aaaaaaaaaa                  ...                           0.0
# aaaaaaaaaaa                 ...                           0.0
# aaaaaaaaaaaaa               ...                           0.0
# aaaaaaaaaaaaaaa             ...                           0.0
# aaaaaaaaaaarriba            ...                           0.0
# aaaaaaaaaayyy               ...                           0.0
# aaaaaaaay                   ...                           0.0
# aaaaaaahh                   ...                           0.0
# aaaaaaahhh                  ...                           0.0
# aaaaahhh                    ...                           0.0
# aaaabeeel                   ...                           0.0
# aaaabue                     ...                           0.0
# aaaaburrido                 ...                           0.0
# aaaadentro                  ...                           0.0
# aaaadfergthyjuikolpñ        ...                           0.0
# aaaag                       ...                           0.0
# aaaaggg                     ...                           0.0
# aaaagua                     ...                           0.0
# aaaaguuuaaannntaaa          ...                           0.0
# aaaah                       ...                           3.0
# aaaahaaah                   ...                           0.0
# ...                         ...                           ...
# aaaammm                     ...                           0.0
# aaaamo                      ...                           0.0
# aaaamooorrr                 ...                           0.0
# aaaamor                     ...                           0.0
# aaaandaa                    ...                           0.0
# aaaanooo                    ...                           0.0
# aaaaoowww                   ...                           0.0
# aaaapa                      ...                           0.0
# aaaapaaalala                ...                           0.0
# aaaaparece                  ...                           0.0
# aaaappaaa                   ...                           0.0
# aaaaqii                     ...                           0.0
# aaaarre                     ...                           0.0
# aaaarriba                   ...                           0.0
# aaaarribaaa                 ...                           0.0
# aaaascooo                   ...                           0.0
# aaaasi                      ...                           0.0
# aaaaspera                   ...                           0.0
# aaaaver                     ...                           0.0
# aaaaw                       ...                           0.0
# aaaawww                     ...                           0.0
# aaaay                       ...                           1.0
# aaaayayai                   ...                           0.0
# aaaayayayaya                ...                           0.0
# aaaaysss                    ...                           0.0
# aaaayy                      ...                           1.0
# aaaayyy                     ...                           0.0
# aaaazucar                   ...                           0.0
# aaaazzzucar                 ...                           0.0
# aaaaàaaahhh                 ...                           0.0
#
#                       santacruz_usuarios  santafe_ocurrencias  \
# a                                   39.0              12751.0
# aa                                   8.0                 10.0
# aaa                                  8.0                 16.0
# aaaa                                 4.0                  5.0
# aaaaa                                0.0                  0.0
# aaaaaa                               0.0                  0.0
# aaaaaaa                              0.0                  0.0
# aaaaaaaa                             0.0                  0.0
# aaaaaaaaa                            0.0                  0.0
# aaaaaaaaaa                           0.0                  0.0
# aaaaaaaaaaa                          0.0                  0.0
# aaaaaaaaaaaaa                        0.0                  0.0
# aaaaaaaaaaaaaaa                      0.0                  0.0
# aaaaaaaaaaarriba                     0.0                  0.0
# aaaaaaaaaayyy                        0.0                  0.0
# aaaaaaaay                            0.0                  0.0
# aaaaaaahh                            0.0                  0.0
# aaaaaaahhh                           0.0                  0.0
# aaaaahhh                             0.0                  0.0
# aaaabeeel                            0.0                  0.0
# aaaabue                              0.0                  0.0
# aaaaburrido                          0.0                  0.0
# aaaadentro                           0.0                  0.0
# aaaadfergthyjuikolpñ                 0.0                  0.0
# aaaag                                0.0                  0.0
# aaaaggg                              0.0                  0.0
# aaaagua                              0.0                  0.0
# aaaaguuuaaannntaaa                   0.0                  0.0
# aaaah                                3.0                  8.0
# aaaahaaah                            0.0                  0.0
# ...                                  ...                  ...
# aaaammm                              0.0                  0.0
# aaaamo                               0.0                  0.0
# aaaamooorrr                          0.0                  0.0
# aaaamor                              0.0                  0.0
# aaaah                              2.0
# aaaahaaah                          0.0
# ...                                ...
# aaaammm                            0.0
# aaaamo                             0.0
# aaaamooorrr                        0.0
# aaaamor                            0.0
# aaaandaa                           0.0
# aaaanooo                           0.0
# aaaaoowww                          0.0
# aaaapa                             0.0
# aaaapaaalala                       0.0
# aaaaparece                         0.0
# aaaappaaa                          0.0
# aaaaqii                            0.0
# aaaarre                            0.0
# aaaarriba                          0.0
# aaaarribaaa                        0.0
# aaaascooo                          0.0
# aaaasi                             0.0
# aaaaspera                          0.0
# aaaaver                            0.0
# aaaaw                              0.0
# aaaawww                            0.0
# aaaay                              0.0
# aaaayayai                          0.0
# aaaayayayaya                       0.0
# aaaaysss                           0.0
# aaaayy                             0.0
# aaaayyy                            0.0
# aaaazucar                          0.0
# aaaazzzucar                        0.0
# aaaaàaaahhh                        0.0
#
# [100 rows x 46 columns]

# %%
columnas_palabras = ["{}_ocurrencias".format(prov) for prov in provincias]
columnas_usuarios = ["{}_usuarios".format(prov) for prov in provincias]

word_df["cantidad_palabras"] = word_df[columnas_palabras].sum(axis=1)
word_df["cantidad_usuarios"] = word_df[columnas_usuarios].sum(axis=1)


len(columnas_palabras), len(columnas_usuarios)
# Out:
# (23, 23)

# %% [markdown]
# # Filtrado de palabras
#
# Saquemos las palabras que ocurren muy pocas veces (menos de 10 ocurrencias, menos de 2 usuarios)

# %%
total_word_df = word_df

word_df = word_df[(word_df["cantidad_palabras"] >= 10) & (word_df["cantidad_usuarios"] >= 3)].copy()


word_df.shape
# Out:
# (33308, 48)

# %% [markdown]
# ## Cálculo de la métrica
#
# Primero, calculemos los logaritmos de las cantidades de usuarios y palabras, y la entropía de las ocurrencias y de usuarios.

# %%
import numpy as np
from scipy.stats import entropy

word_df["log_usuarios"] = np.log(word_df["cantidad_usuarios"])
word_df["log_palabras"] = np.log(word_df["cantidad_palabras"])

word_df["entropia_palabras"] = word_df[columnas_palabras].apply(entropy, axis=1, raw=True)
word_df["entropia_usuarios"] = word_df[columnas_usuarios].apply(entropy, axis=1, raw=True)

# %% [markdown]
# Calculemos la métrica. Recordemos que su fórmula era
#
#
# $$
# IV(w) =  log(f(w)) * (M - H(p|w))
# $$
#
# donde $log(f(w))$ es el logaritmo de la cantidad de veces que aparece la palabra en cada provincia o la cantidad de usuarios,  $M$ es la entropía máxima ($log(23)$) y $H(p|w)$ es la entropía de la palabra (bien para ocurrencias a secas, o bien para usuarios).
#
# Para escalarlos, normalizamos entre 0 y 1 el logaritmo dividiendo por el máximo.

# %%
log_tf_palabras = word_df["log_palabras"] / word_df["log_palabras"].max()
log_tf_usuarios = word_df["log_usuarios"] / word_df["log_usuarios"].max()


word_df["metrica_palabras"] = log_tf_palabras * (np.log(23) - word_df["entropia_palabras"])
word_df["metrica_usuarios"] = log_tf_usuarios * (np.log(23) - word_df["entropia_usuarios"])

# %% [markdown]
# Ahora, ordenemos todo por la métrica de usuarios!

# %%
word_df.sort_values("metrica_usuarios", ascending=False, inplace=True)

# %% [markdown]
# Veamos las 100 primeras palabras de la métrica
#
# Obs: si cambiamos `range(0, 100)` por `range(a, b)` podremos ver todas las palabras entre las posiciones a y b del listado

# %%
def mostrar_palabras(desde, hasta):
  per_line = 4

  for i in range(desde, hasta+1):
    print("{:<4} -- {:<16}".format(i+1, word_df.index[i]), end='')
    if (i+1) % per_line == 0:
      print('')

mostrar_palabras(0, 200)
# Out:
# 1    -- ush             2    -- fsa             3    -- rada            4    -- argel
# 5    -- patagones       6    -- jei             7    -- obera           8    -- rg
# 9    -- tolhuin         10   -- yarca           11   -- poec            12   -- chayero
# 13   -- riojano         14   -- riojanos        15   -- viedma          16   -- oberá
# 17   -- malpegue        18   -- sanagasta       19   -- toay            20   -- bragado
# 21   -- riojana         22   -- nae             23   -- ctes            24   -- reviro
# 25   -- chilecito       26   -- qlq             27   -- pachata         28   -- chimbas
# 29   -- cldo            30   -- nqn             31   -- mbae            32   -- posadas
# 33   -- beder           34   -- nox             35   -- riojanas        36   -- blv
# 37   -- aijue           38   -- edelar          39   -- chayar          40   -- anga
# 41   -- músicas         42   -- ushuaia         43   -- copi            44   -- chivilcoy
# 45   -- chamical        46   -- clda            47   -- saeta           48   -- tilly
# 49   -- quattro         50   -- ais             51   -- tkt             52   -- bombola
# 53   -- pocito          54   -- mdt             55   -- bosetti         56   -- cdelu
# 57   -- comodoro        58   -- chipitas        59   -- pair            60   -- ozono
# 61   -- cldos           62   -- mitai           63   -- zapala          64   -- fne
# 65   -- choele          66   -- tafi            67   -- charata         68   -- quedarla
# 69   -- unsa            70   -- formosa         71   -- plottier        72   -- goa
# 73   -- rrrmano         74   -- kalima          75   -- portho          76   -- pelay
# 77   -- piadinas        78   -- brix            79   -- mnes            80   -- ws
# 81   -- buddha          82   -- kolor           83   -- juntadera       84   -- unlar
# 85   -- engau           86   -- roka            87   -- ndv             88   -- bk
# 89   -- catamarqueño    90   -- chepes          91   -- itu             92   -- asada
# 93   -- sgo             94   -- wha             95   -- secamente       96   -- rioja
# 97   -- esperanto       98   -- nio             99   -- qvc             100  -- cipo
# 101  -- bolasear        102  -- aimogasta       103  -- bowen           104  -- jumeal
# 105  -- rodeooo         106  -- kraka           107  -- edese           108  -- yagua
# 109  -- vallerga        110  -- sanagasteño     111  -- cldaaa          112  -- lamarque
# 113  -- corvina         114  -- herradura       115  -- palazzo         116  -- jujeña
# 117  -- asar            118  -- tdf             119  -- salamanca       120  -- chaya
# 121  -- tereee          122  -- chalet          123  -- musicas         124  -- zonda
# 125  -- merlo           126  -- rodeo           127  -- chupapija       128  -- nnv
# 129  -- chiri           130  -- obe             131  -- náutico         132  -- pichado
# 133  -- famatina        134  -- globales        135  -- bols            136  -- yarco
# 137  -- cafa            138  -- formoseños      139  -- conser          140  -- olta
# 141  -- taj             142  -- tili            143  -- bolaseo         144  -- qt
# 145  -- oyo             146  -- recep           147  -- nsq             148  -- vendimia
# 149  -- yaki            150  -- placi           151  -- chayas          152  -- inkier
# 153  -- epe             154  -- aij             155  -- dlo             156  -- chocon
# 157  -- sapucay         158  -- ambato          159  -- cldooo          160  -- capiovi
# 161  -- sinf            162  -- chivil          163  -- logroño         164  -- pircas
# 165  -- wika            166  -- akil            167  -- catamarca       168  -- concordia
# 169  -- yf              170  -- lb              171  -- empinga         172  -- pw
# 173  -- resis           174  -- otaria          175  -- mansas          176  -- sanjuaninos
# 177  -- pollerear       178  -- santiagueña     179  -- festi           180  -- atina
# 181  -- tranco          182  -- mba             183  -- catamarqueños   184  -- santiagueño
# 185  -- puee            186  -- padua           187  -- calafate        188  -- gurisa
# 189  -- grutas          190  -- pué             191  -- carnera         192  -- sanma
# 193  -- yuto            194  -- empingue        195  -- montecarlo      196  -- changada
# 197  -- cem             198  -- conesa          199  -- alunada         200  -- cente
# 201  -- llanos

# %%
def info_palabra(palabra):
  """
  Información de la palabra dada.
  
  Argumentos:
  -----------
  
  palabra: string
    Una palabra perteneciente al vocabulario empleado
  """
  row = word_df.loc[palabra]
  
  print(palabra)
  
  user_row = row[columnas_usuarios]

  user_row = user_row.sort_values(ascending=False)
  
  
  
  print("Provincias donde más se usa:")
  
  for (column, value) in user_row.iteritems():
      if value > 0:
          provincia = column.split("_")[0]
          print("{:<15} -- {:<2} usuarios".format(provincia, int(value)))
          
  print("\n\nAlgunos ejemplos:")
  
  for (i, tweet) in zip(range(20), word_to_tweets[palabra]):
      print(" {:<16} -- {}".format(tweet[0], tweet[1]))
  

info_palabra("asada")
# Out:
# asada
# Provincias donde más se usa:
# sanjuan         -- 13 usuarios
# mendoza         -- 12 usuarios
# corrientes      -- 3  usuarios
# santafe         -- 1  usuarios
# santiago        -- 1  usuarios
# sanluis         -- 1  usuarios
#
#
# Algunos ejemplos:
#  corrientes       -- El día amerita un buen asada de medio dia
#  mendoza          -- Ya fue, estoy asada
#  mendoza          -- Estoy asada
#  sanjuan          -- Que asada con instagram 😭😭😭
#  sanjuan          -- Que asada estoy 😣😣
#  mendoza          -- Estoy asada y con ganas de romper todo. Me pasa por pelotudaaaaaaáaaaa a a
#  sanjuan          -- estoy muy muy asada 🔫
#  sanjuan          -- Que asada que estoy, como me van a cambiar 🔫
#  sanjuan          -- tan asada puedo estar?
#  sanjuan          -- Entre que estoy asada con la minita y me llegan las notificaciones de sus tw quiero largar el teléfono por la ventana...
#  sanjuan          -- Vengo cínica, fobica, cruda, hervida y asada por vos..
#  sanjuan          -- No puedo estar tan asada.
#  sanjuan          -- Que asada que estoy😪😪
#  sanjuan          -- Demasiado asada estoy.
#  sanjuan          -- Ojjj que asada estoy.
#  sanjuan          -- Ojjj que asada loco.
#  sanjuan          -- Creo que estoy demasiado asada, no quiero hacer nada.
#  sanjuan          -- Que bronca me dan estas cosas, estoy muy asada loco.
#  sanjuan          -- La concha del pato. Que asada estoy.
#  sanjuan          -- No loco que asada.
